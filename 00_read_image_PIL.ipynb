# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# # Read image file

# %%
img_path = "./img/2valk.jpg"
im = Image.open(img_path)

# %%
im.size
# Out:
# (2048, 1818)

# %% [markdown]
# > Width x Height

# %%
np.array(im).shape
# Out:
# (1818, 2048, 3)

# %% [markdown]
# > Height x Width x Channel(RGB)

# %% [markdown]
# # to numpy array

# %%
arr_im = np.array(im)

# %%
arr_im.shape
# Out:
# (1818, 2048, 3)

# %%
arr_im
# Out:
# array([[[222, 225, 242],
#         [197, 200, 217],
#         [195, 198, 213],
#         ...,
#         [169, 177, 196],
#         [169, 177, 196],
#         [169, 177, 196]],
#
#        [[162, 168, 184],
#         [122, 128, 144],
#         [110, 116, 130],
#         ...,
#         [ 19,  27,  46],
#         [ 19,  27,  46],
#         [ 19,  27,  46]],
#
#        [[164, 172, 185],
#         [123, 131, 144],
#         [109, 117, 130],
#         ...,
#         [ 18,  26,  47],
#         [ 18,  26,  47],
#         [ 18,  26,  47]],
#
#        ...,
#
#        [[132, 130, 133],
#         [ 68,  66,  69],
#         [ 60,  58,  61],
#         ...,
#         [199, 159, 123],
#         [200, 160, 124],
#         [204, 164, 128]],
#
#        [[104, 102, 105],
#         [ 61,  59,  62],
#         [ 72,  70,  73],
#         ...,
#         [199, 156, 121],
#         [199, 156, 121],
#         [193, 150, 115]],
#
#        [[ 99,  97, 100],
#         [ 57,  55,  58],
#         [ 68,  66,  69],
#         ...,
#         [195, 152, 117],
#         [194, 151, 116],
#         [189, 146, 111]]], dtype=uint8)

# %% [markdown]
# # Resize image

# %%
new_im = im.resize((np.array(im.size)//4).astype(int))

# %%
new_im.size
# Out:
# (512, 454)

# %% [markdown]
# # Plot image

# %%
plt.imshow(arr_im)
